# %%
import pandas as pd
from collections import Counter

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the CSV file
file_path = './mapped.csv'
df = pd.read_csv(file_path)

# Combine the "issue" and "solution" columns
issues = df['issue'].dropna().str.lower().str.strip().str.split(',').explode()
solutions = df['solution'].dropna().str.lower().str.strip().str.split(',').explode()

# Count the frequency of each piece of string
issue_counts = Counter(issues.str.strip())
solution_counts = Counter(solutions.str.strip())

# %% [markdown]
# # Frequency

# %%
issues_tax = pd.read_csv('./issue_theme_summary.csv')
issue_sub_counts = Counter()
issue_theme_counts = Counter()
for issue, count in issue_counts.items():
    issue_mapping = issues_tax[issues_tax["Code"].str.strip().str.lower() == issue.lower()]
    sub_theme = issue_mapping["Sub-theme"].values.tolist()
    if not sub_theme:
        print(f">> Unknown issue: {issue}")
    else:
        issue_sub_counts[sub_theme[0]] += count
        issue_theme_counts[issue_mapping["Theme"].str.strip().values.tolist()[0]] += count

print("\nIssue Sub-Theme Frequencies:")
for category, count in issue_sub_counts.most_common():
    print(f"{category}: {count}")

print("\nIssue Theme Frequencies:")
for category, count in issue_theme_counts.most_common():
    print(f"{category}: {count}")
# Out:
# >> Unknown issue:
#
# Issue Sub-Theme Frequencies:
# System Runtime Compatibility Concerns: 325
# Code Execution Security Concerns: 229
# Security of Dependencies Concerns: 201
# Deployment and Infrastructure Security Concerns: 182
# Memory and Resource Security Concerns: 162
# External Service Usage Security Concerns: 138
# Model Output and Content Control Concerns: 101
# Model Input and Prompt Security Concerns: 63
# Data Exposure Concerns: 48
# Secure Communication Concerns: 47
# Data Integrity Concerns: 29
#
# Issue Theme Frequencies:
# System & Software Security Concerns: 945
# External Tools & Ecosystem Security Concerns: 339
# Model Security Concerns: 164
# Data Security Concerns: 77

# %%
solution_tax = pd.read_csv('./solution_theme_summary.csv')
solution_sub_counts = Counter()
solution_theme_counts = Counter()
for solution, count in solution_counts.items():
    solution_mapping = solution_tax[solution_tax["Code"].str.strip().str.lower() == solution.lower()]
    sub_theme = solution_mapping["Sub-theme"].values.tolist()
    if not sub_theme:
        print(f">> Unknown solution: {solution}")
    else:
        solution_sub_counts[sub_theme[0]] += count
        solution_theme_counts[solution_mapping["Theme"].str.strip().values.tolist()[0]] += count

print("\nsolution Sub-Theme Frequencies:")
for category, count in solution_sub_counts.most_common():
    print(f"{category}: {count}")

print("\nsolution Theme Frequencies:")
for category, count in solution_theme_counts.most_common():
    print(f"{category}: {count}")
# Out:
# >> Unknown solution:
#
# solution Sub-Theme Frequencies:
# Dependency & Supply Chain Security: 192
# Secure Coding & Execution: 153
# Secure Infrastructure & Deployment: 124
# Secure Runtime & Environment Configuration: 92
# Security Governance & Assurance: 60
# Platform Identity & Access Management: 37
# Model Security Solutions: 33
# Data Security Solutions: 6
#
# solution Theme Frequencies:
# System & Software Security Solutions: 369
# External Tools & Ecosystem Security Solutions: 289
# Model Security Solutions: 33
# Data Security Solutions: 6

# %% [markdown]
# # Coverage

# %%
issues_tax = pd.read_csv('./issue_theme_summary.csv')

# Create mappings for efficient lookup
issue_to_sub = pd.Series(
    issues_tax["Sub-theme"].values,
    index=issues_tax.Code.str.strip().str.lower()
).to_dict()
issue_to_theme = pd.Series(
    issues_tax.Theme.str.strip().values,
    index=issues_tax.Code.str.strip().str.lower()
).to_dict()

# Initialize counters for coverage
sub_theme_coverage = Counter()
theme_coverage = Counter()

# Filter dataframe and get total document count
docs_with_issues = df.dropna(subset=['issue'])
total_docs = 753

# Iterate over each document to calculate coverage
for _, row in docs_with_issues.iterrows():
    issues_in_doc = [issue.strip().lower() for issue in row['issue'].split(',') if issue.strip()]

    # Find unique sub-themes and themes in the current document
    doc_sub_themes = set()
    doc_themes = set()

    for code in issues_in_doc:
        sub = issue_to_sub.get(code)
        theme = issue_to_theme.get(code)
        if sub:
            doc_sub_themes.add(sub)
        if theme:
            doc_themes.add(theme)

    # Increment coverage count for each unique theme found
    for sub in doc_sub_themes:
        sub_theme_coverage[sub] += 1
    for theme in doc_themes:
        theme_coverage[theme] += 1

print(f"\nTotal documents with issues: {total_docs}")

print("\nIssue Sub-Theme Coverage:")
for category, count in sub_theme_coverage.most_common():
    percentage = (count / total_docs) * 100
    print(f"{category}: {count} ({percentage:.2f}%)")

print("\nIssue Theme Coverage:")
for category, count in theme_coverage.most_common():
    percentage = (count / total_docs) * 100
    print(f"{category}: {count} ({percentage:.2f}%)")
# Out:
# Total documents with issues: 753
#
# Issue Sub-Theme Coverage:
# System Runtime Compatibility Concerns: 260 (34.53%)
# Security of Dependencies Concerns: 181 (24.04%)
# Code Execution Security Concerns: 170 (22.58%)
# Deployment and Infrastructure Security Concerns: 163 (21.65%)
# Memory and Resource Security Concerns: 135 (17.93%)
# External Service Usage Security Concerns: 127 (16.87%)
# Model Output and Content Control Concerns: 81 (10.76%)
# Model Input and Prompt Security Concerns: 57 (7.57%)
# Secure Communication Concerns: 47 (6.24%)
# Data Exposure Concerns: 45 (5.98%)
# Data Integrity Concerns: 28 (3.72%)
#
# Issue Theme Coverage:
# System & Software Security Concerns: 560 (74.37%)
# External Tools & Ecosystem Security Concerns: 282 (37.45%)
# Model Security Concerns: 107 (14.21%)
# Data Security Concerns: 68 (9.03%)

# %%
solution_tax = pd.read_csv('./solution_theme_summary.csv')

# Create mappings for efficient lookup
solution_to_sub = pd.Series(
    solution_tax["Sub-theme"].values,
    index=solution_tax.Code.str.strip().str.lower()
).to_dict()
solution_to_theme = pd.Series(
    solution_tax.Theme.str.strip().values,
    index=solution_tax.Code.str.strip().str.lower()
).to_dict()

# Initialize counters for coverage
solution_sub_theme_coverage = Counter()
solution_theme_coverage = Counter()

# Filter dataframe and get total document count
docs_with_solutions = df.dropna(subset=['solution'])
total_docs = 753

# Iterate over each document to calculate coverage
for _, row in docs_with_solutions.iterrows():
    solutions_in_doc = [solution.strip().lower() for solution in row['solution'].split(',') if solution.strip()]

    # Find unique sub-themes and themes in the current document
    doc_sub_themes = set()
    doc_themes = set()

    for code in solutions_in_doc:
        sub = solution_to_sub.get(code)
        theme = solution_to_theme.get(code)
        if sub:
            doc_sub_themes.add(sub)
        if theme:
            doc_themes.add(theme)

    # Increment coverage count for each unique theme found
    for sub in doc_sub_themes:
        solution_sub_theme_coverage[sub] += 1
    for theme in doc_themes:
        solution_theme_coverage[theme] += 1

print(f"\nTotal documents with solutions: {total_docs}")

print("\nSolution Sub-Theme Coverage:")
for category, count in solution_sub_theme_coverage.most_common():
    percentage = (count / total_docs) * 100
    print(f"{category}: {count} ({percentage:.2f}%)")

print("\nSolution Theme Coverage:")
for category, count in solution_theme_coverage.most_common():
    percentage = (count / total_docs) * 100
    print(f"{category}: {count} ({percentage:.2f}%)")
# Out:
# Total documents with solutions: 753
#
# Solution Sub-Theme Coverage:
# Dependency & Supply Chain Security: 178 (23.64%)
# Secure Coding & Execution: 124 (16.47%)
# Secure Infrastructure & Deployment: 104 (13.81%)
# Secure Runtime & Environment Configuration: 86 (11.42%)
# Security Governance & Assurance: 57 (7.57%)
# Model Security Solutions: 32 (4.25%)
# Platform Identity & Access Management: 32 (4.25%)
# Data Security Solutions: 5 (0.66%)
#
# Solution Theme Coverage:
# System & Software Security Solutions: 261 (34.66%)
# External Tools & Ecosystem Security Solutions: 259 (34.40%)
# Model Security Solutions: 32 (4.25%)
# Data Security Solutions: 5 (0.66%)

# %%
file_path = './mapped.csv'
df = pd.read_csv(file_path)

# Create issue-solution mapping
issue_solution_pairs = []

# Process each row in the dataset
for _, row in df.dropna(subset=['issue', 'solution']).iterrows():
    # Extract issues and solutions from the row
    row_issues = [issue.strip().lower() for issue in row['issue'].split(',') if issue.strip()]
    row_solutions = [solution.strip().lower() for solution in row['solution'].split(',') if solution.strip()]

    # Create all possible pairs for this row
    for issue in row_issues:
        for solution in row_solutions:
            issue_solution_pairs.append((issue, solution))

# Count the frequency of each pair
pair_counts = Counter(issue_solution_pairs)

# Create and display the output
# print("from_code,to_code,count")
# for (issue, solution), count in pair_counts.items():
#     print(f"{issue},{solution},{count}")

data_rows = []

print("from_code,to_code,issue_sub_theme,solution_sub_theme,count")
for (issue, solution), count in pair_counts.items():
    # Get issue sub-theme
    issue_mapping = issues_tax[issues_tax["Code"].str.strip().str.lower() == issue.lower()]
    issue_sub_theme = issue_mapping["Sub-theme"].values.tolist()
    issue_sub = issue_sub_theme[0] if issue_sub_theme else "Unknown"

    # Get solution sub-theme
    solution_mapping = solution_tax[solution_tax["Code"].str.strip().str.lower() == solution.lower()]
    solution_sub_theme = solution_mapping["Sub-theme"].values.tolist()
    solution_sub = solution_sub_theme[0] if solution_sub_theme else "Unknown"

    print(f"{issue},{solution},{issue_sub},{solution_sub},{count}")
    data_rows.append({
        "issue": issue,
        "solution": solution,
        "issue_sub_theme": issue_sub,
        "solution_sub_theme": solution_sub,
        "count": count
    })

# Create DataFrame from the collected data
pairs_df = pd.DataFrame(data_rows)

# Display the DataFrame
print(pairs_df.head())
print(f"Total rows: {len(pairs_df)}")

pairs_df.drop(columns=['issue', 'solution'], inplace=True)
pairs_df.groupby(['issue_sub_theme', 'solution_sub_theme']).sum().reset_index()



issue_subs = (pairs_df['issue_sub_theme'].str.replace('concerns', '', case=False).str.strip())
              # .str.replace('security', '',case=False).str.strip(),)
solution_subs = pairs_df['solution_sub_theme'].str.replace('concerns', '', case=False).str.strip(),

# Assuming pairs_df has columns: 'issue_sub_theme', 'solution_sub_theme', 'count'
pivot_table = pairs_df.pivot_table(
    index=solution_subs,
    columns=issue_subs,
    # index=issue_subs,
    # columns=solution_subs,
    values='count',
    fill_value=0
)

# Normalize to percentage by row (issue_sub_theme)
pivot_table_percent = pivot_table.div(pivot_table.sum(axis=1), axis=0) * 100

plt.figure(figsize=(12, 8))
sns.heatmap(
    pivot_table_percent, annot=True, fmt=".1f", cmap="crest",
    linewidth=.5,
    square=True,
    # cbar_kws={"shrink": 0.5}
)
plt.xlabel('Issue Sub-Themes')
plt.ylabel('Solution Sub-Themes')

# plt.xlabel('Solution Sub-Themes')
# plt.ylabel('Issue Sub-Themes')
plt.title('Heatmap of Issue vs Solution Sub-Themes')
# plt.show()

plt.subplots_adjust(bottom=0.4)
plt.xticks(rotation=45, ha='right')

plt.savefig('./issue_solution_heatmap.pdf', bbox_inches='tight', pad_inches=0)
plt.show()
# Out:
# from_code,to_code,issue_sub_theme,solution_sub_theme,count
# environmental compatibility issues,modify configurations for enhanced compatibility,System Runtime Compatibility Concerns,Secure Runtime & Environment Configuration,15
# environmental compatibility issues,modify configurations for enhanced security,System Runtime Compatibility Concerns,Secure Infrastructure & Deployment,6
# deployment misconfigurations,modify configurations for enhanced compatibility,Deployment and Infrastructure Security Concerns,Secure Runtime & Environment Configuration,28
# deployment misconfigurations,modify configurations for enhanced security,Deployment and Infrastructure Security Concerns,Secure Infrastructure & Deployment,50
# system resource exhaustions,modify configurations for enhanced security,Memory and Resource Security Concerns,Secure Infrastructure & Deployment,13
# deployment misconfigurations,dependency version upgrade,Deployment and Infrastructure Security Concerns,Dependency & Supply Chain Security,17
# file format and loading incompatibility,dependency version upgrade,System Runtime Compatibility Concerns,Dependency & Supply Chain Security,18
# file format and loading incompatibility,modify configurations for enhanced compatibility,System Runtime Compatibility Concerns,Secure Runtime & Environment Configuration,11
# file format and loading incompatibility,modify configurations for enhanced security,System Runtime Compatibility Concerns,Secure Infrastructure & Deployment,23
# software dependencies compatibility issues,dependency version upgrade,System Runtime Compatibility Concerns,Dependency & Supply Chain Security,46
# software dependencies compatibility issues,modify configurations for enhanced compatibility,System Runtime Compatibility Concerns,Secure Runtime & Environment Configuration,20
# software dependencies compatibility issues,modify configurations for enhanced security,System Runtime Compatibility Concerns,Secure Infrastructure & Deployment,18
# outdated third-party dependency/package contains vulnerabilities,dependency version upgrade,Security of Dependencies Concerns,Dependency & Supply Chain Security,69
# outdated third-party dependency/package contains vulnerabilities,modify configurations for enhanced compatibility,Security of Dependencies Concerns,Secure Runtime & Environment Configuration,4
# outdated third-party dependency/package contains vulnerabilities,modify configurations for enhanced security,Security of Dependencies Concerns,Secure Infrastructure & Deployment,3
# environmental compatibility issues,dependency version upgrade,System Runtime Compatibility Concerns,Dependency & Supply Chain Security,12
# flawed or insecure prompt/template design,secure prompt techniques,Model Input and Prompt Security Concerns,Model Security Solutions,16
# harmful/undesired model output,secure prompt techniques,Model Output and Content Control Concerns,Model Security Solutions,14
# failure of model generation control parameters,secure prompt techniques,Model Output and Content Control Concerns,Model Security Solutions,4
# system resource exhaustions,secure prompt techniques,Memory and Resource Security Concerns,Model Security Solutions,2
# deployment misconfigurations,secure prompt techniques,Deployment and Infrastructure Security Concerns,Model Security Solutions,4
# file format and loading incompatibility,secure prompt techniques,System Runtime Compatibility Concerns,Model Security Solutions,4
# software dependencies compatibility issues,secure prompt techniques,System Runtime Compatibility Concerns,Model Security Solutions,5
# system resource exhaustions,component removal/replacement,Memory and Resource Security Concerns,Dependency & Supply Chain Security,5
# environmental compatibility issues,component removal/replacement,System Runtime Compatibility Concerns,Dependency & Supply Chain Security,4
# software dependencies compatibility issues,component removal/replacement,System Runtime Compatibility Concerns,Dependency & Supply Chain Security,9
# software dependencies compatibility issues,input validation and sanitization,System Runtime Compatibility Concerns,Secure Coding & Execution,1
# harmful/undesired model output,modify configurations for enhanced security,Model Output and Content Control Concerns,Secure Infrastructure & Deployment,10
# system resource exhaustions,memory safety & resource management techniques,Memory and Resource Security Concerns,Secure Runtime & Environment Configuration,27
# environmental compatibility issues,memory safety & resource management techniques,System Runtime Compatibility Concerns,Secure Runtime & Environment Configuration,4
# flawed or insecure prompt/template design,modify configurations for enhanced security,Model Input and Prompt Security Concerns,Secure Infrastructure & Deployment,7
# using insecure (default) deployment configurations,secure prompt techniques,Deployment and Infrastructure Security Concerns,Model Security Solutions,1
# using insecure (default) deployment configurations,modify configurations for enhanced security,Deployment and Infrastructure Security Concerns,Secure Infrastructure & Deployment,10
# file format and loading incompatibility,secure code execution implementation,System Runtime Compatibility Concerns,Secure Coding & Execution,6
# system/software unsafe deserialization,secure code execution implementation,Code Execution Security Concerns,Secure Coding & Execution,17
# system/software unsafe deserialization,modify configurations for enhanced security,Code Execution Security Concerns,Secure Infrastructure & Deployment,1
# system/software unsafe deserialization,dependency version upgrade,Code Execution Security Concerns,Dependency & Supply Chain Security,5
# deployment misconfigurations,secure code execution implementation,Deployment and Infrastructure Security Concerns,Secure Coding & Execution,7
# system resource exhaustions,secure deployment strategies,Memory and Resource Security Concerns,Secure Infrastructure & Deployment,4
# system resource exhaustions,use of dependency management tools,Memory and Resource Security Concerns,Dependency & Supply Chain Security,1
# deployment misconfigurations,secure deployment strategies,Deployment and Infrastructure Security Concerns,Secure Infrastructure & Deployment,24
# deployment misconfigurations,use of dependency management tools,Deployment and Infrastructure Security Concerns,Dependency & Supply Chain Security,1
# improper authentication and authorization,implementation of authentication mechanisms,External Service Usage Security Concerns,Platform Identity & Access Management,19
# deployment misconfigurations,user consent and warning mechanisms,Deployment and Infrastructure Security Concerns,Security Governance & Assurance,2
# unaware compromised infrastructures,user consent and warning mechanisms,Deployment and Infrastructure Security Concerns,Security Governance & Assurance,2
# using insecure (default) deployment configurations,user consent and warning mechanisms,Deployment and Infrastructure Security Concerns,Security Governance & Assurance,5
# outdated third-party dependency/package contains vulnerabilities,use of dependency management tools,Security of Dependencies Concerns,Dependency & Supply Chain Security,2
# data leakages during model training/inference/usage,use of dependency management tools,Data Exposure Concerns,Dependency & Supply Chain Security,1
# system resource exhaustions,modify configurations for enhanced compatibility,Memory and Resource Security Concerns,Secure Runtime & Environment Configuration,8
# limited capabilities of security tools,adoption/enhancment of security scanning & testing tools,External Service Usage Security Concerns,Security Governance & Assurance,8
# harmful/undesired model output,adoption/enhancment of security scanning & testing tools,Model Output and Content Control Concerns,Security Governance & Assurance,2
# harmful/undesired model output,content safety filters,Model Output and Content Control Concerns,Model Security Solutions,7
# unreliable content filtering mechanism for model output,content safety filters,Model Output and Content Control Concerns,Model Security Solutions,3
# unreliable content filtering mechanism for model output,adoption/enhancment of security scanning & testing tools,Model Output and Content Control Concerns,Security Governance & Assurance,1
# system/software arbitrary code execution,user consent and warning mechanisms,Code Execution Security Concerns,Security Governance & Assurance,6
# system/software arbitrary code execution,dependency source vetting and control,Code Execution Security Concerns,Dependency & Supply Chain Security,10
# data leakages during model training/inference/usage,user consent and warning mechanisms,Data Exposure Concerns,Security Governance & Assurance,5
# data leakages during model training/inference/usage,dependency source vetting and control,Data Exposure Concerns,Dependency & Supply Chain Security,2
# use of untrusted dependency sources,user consent and warning mechanisms,Security of Dependencies Concerns,Security Governance & Assurance,3
# use of untrusted dependency sources,dependency source vetting and control,Security of Dependencies Concerns,Dependency & Supply Chain Security,16
# unaware compromised infrastructures,dependency source vetting and control,Deployment and Infrastructure Security Concerns,Dependency & Supply Chain Security,1
# limited capabilities of security tools,dependency source vetting and control,External Service Usage Security Concerns,Dependency & Supply Chain Security,6
# system/software unsafe deserialization,dependency source vetting and control,Code Execution Security Concerns,Dependency & Supply Chain Security,10
# risk of malicious codes in dependencies/plugins,dependency source vetting and control,Security of Dependencies Concerns,Dependency & Supply Chain Security,15
# system/software unsafe deserialization,secure file format adoption,Code Execution Security Concerns,Secure Coding & Execution,35
# system/software path traversal,input validation and sanitization,Code Execution Security Concerns,Secure Coding & Execution,4
# data leakages during model training/inference/usage,adoption/enhancment of security scanning & testing tools,Data Exposure Concerns,Security Governance & Assurance,1
# data leakages during model training/inference/usage,adoption of vulnerability disclosure and reporting process,Data Exposure Concerns,Security Governance & Assurance,1
# flawed or insecure prompt/template design,input validation and sanitization,Model Input and Prompt Security Concerns,Secure Coding & Execution,3
# model input manipulations and evasions,secure prompt techniques,Model Input and Prompt Security Concerns,Model Security Solutions,7
# model input manipulations and evasions,input validation and sanitization,Model Input and Prompt Security Concerns,Secure Coding & Execution,11
# system/software arbitrary code execution,secure file format adoption,Code Execution Security Concerns,Secure Coding & Execution,16
# data leakages during model training/inference/usage,data anonymization,Data Exposure Concerns,Data Security Solutions,2
# data leakages during model training/inference/usage,data guardrails,Data Exposure Concerns,Data Security Solutions,3
# data leakages during model training/inference/usage,secure deployment strategies,Data Exposure Concerns,Secure Infrastructure & Deployment,2
# data leakages during model training/inference/usage,secure file format adoption,Data Exposure Concerns,Secure Coding & Execution,1
# deployment misconfigurations,data anonymization,Deployment and Infrastructure Security Concerns,Data Security Solutions,1
# deployment misconfigurations,data guardrails,Deployment and Infrastructure Security Concerns,Data Security Solutions,1
# deployment misconfigurations,secure file format adoption,Deployment and Infrastructure Security Concerns,Secure Coding & Execution,3
# system/software unsafe deserialization,data anonymization,Code Execution Security Concerns,Data Security Solutions,1
# system/software unsafe deserialization,data guardrails,Code Execution Security Concerns,Data Security Solutions,1
# system/software unsafe deserialization,secure deployment strategies,Code Execution Security Concerns,Secure Infrastructure & Deployment,3
# improper authentication and authorization,secure file format adoption,External Service Usage Security Concerns,Secure Coding & Execution,1
# improper authentication and authorization,secure deployment strategies,External Service Usage Security Concerns,Secure Infrastructure & Deployment,5
# improper authentication and authorization,dependency source vetting and control,External Service Usage Security Concerns,Dependency & Supply Chain Security,1
# system/software arbitrary code execution,secure deployment strategies,Code Execution Security Concerns,Secure Infrastructure & Deployment,10
# using insecure (default) deployment configurations,secure file format adoption,Deployment and Infrastructure Security Concerns,Secure Coding & Execution,1
# using insecure (default) deployment configurations,secure deployment strategies,Deployment and Infrastructure Security Concerns,Secure Infrastructure & Deployment,8
# using insecure (default) deployment configurations,dependency source vetting and control,Deployment and Infrastructure Security Concerns,Dependency & Supply Chain Security,3
# deployment misconfigurations,dependency source vetting and control,Deployment and Infrastructure Security Concerns,Dependency & Supply Chain Security,3
# using insecure (default) deployment configurations,implementation of secure default configurations,Deployment and Infrastructure Security Concerns,Secure Infrastructure & Deployment,9
# unauthorized data collection during usage,implementation of secure default configurations,Data Exposure Concerns,Secure Infrastructure & Deployment,1
# unauthorized data collection during usage,user consent and warning mechanisms,Data Exposure Concerns,Security Governance & Assurance,3
# deployment misconfigurations,implementation of secure default configurations,Deployment and Infrastructure Security Concerns,Secure Infrastructure & Deployment,5
# improper authentication and authorization,component removal/replacement,External Service Usage Security Concerns,Dependency & Supply Chain Security,1
# improper authentication and authorization,modify configurations for enhanced security,External Service Usage Security Concerns,Secure Infrastructure & Deployment,7
# using insecure (default) deployment configurations,component removal/replacement,Deployment and Infrastructure Security Concerns,Dependency & Supply Chain Security,1
# outdated third-party dependency/package contains vulnerabilities,component removal/replacement,Security of Dependencies Concerns,Dependency & Supply Chain Security,10
# deployment misconfigurations,component removal/replacement,Deployment and Infrastructure Security Concerns,Dependency & Supply Chain Security,5
# software dependencies compatibility issues,use of isolated processes for dependencies,System Runtime Compatibility Concerns,Dependency & Supply Chain Security,3
# outdated third-party dependency/package contains vulnerabilities,use of isolated processes for dependencies,Security of Dependencies Concerns,Dependency & Supply Chain Security,1
# outdated third-party dependency/package contains vulnerabilities,secure deployment strategies,Security of Dependencies Concerns,Secure Infrastructure & Deployment,2
# system/software unsafe deserialization,adoption/enhancment of security scanning & testing tools,Code Execution Security Concerns,Security Governance & Assurance,6
# system/software arbitrary code execution,adoption/enhancment of security scanning & testing tools,Code Execution Security Concerns,Security Governance & Assurance,5
# use of untrusted dependency sources,secure file format adoption,Security of Dependencies Concerns,Secure Coding & Execution,4
# use of untrusted dependency sources,adoption/enhancment of security scanning & testing tools,Security of Dependencies Concerns,Security Governance & Assurance,4
# system/software unsafe deserialization,secure deserialization practices,Code Execution Security Concerns,Secure Coding & Execution,13
# improper authentication and authorization,authorization & permission controls,External Service Usage Security Concerns,Platform Identity & Access Management,13
# deployment misconfigurations,authorization & permission controls,Deployment and Infrastructure Security Concerns,Platform Identity & Access Management,3
# system/software arbitrary code execution,secure code execution implementation,Code Execution Security Concerns,Secure Coding & Execution,43
# use of untrusted dependency sources,secure code execution implementation,Security of Dependencies Concerns,Secure Coding & Execution,8
# use of untrusted dependency sources,secure deployment strategies,Security of Dependencies Concerns,Secure Infrastructure & Deployment,4
# outdated third-party dependency/package contains vulnerabilities,secure code execution implementation,Security of Dependencies Concerns,Secure Coding & Execution,2
# risk of malicious codes in dependencies/plugins,secure code execution implementation,Security of Dependencies Concerns,Secure Coding & Execution,12
# risk of malicious codes in dependencies/plugins,modify configurations for enhanced security,Security of Dependencies Concerns,Secure Infrastructure & Deployment,3
# improper authentication and authorization,secure code execution implementation,External Service Usage Security Concerns,Secure Coding & Execution,3
# risk of malicious codes in dependencies/plugins,secure file format adoption,Security of Dependencies Concerns,Secure Coding & Execution,7
# unsafe os command execution and environment variable handling,secure code execution implementation,Code Execution Security Concerns,Secure Coding & Execution,11
# limited capabilities of security tools,secure file format adoption,External Service Usage Security Concerns,Secure Coding & Execution,5
# file format and loading incompatibility,dependency source vetting and control,System Runtime Compatibility Concerns,Dependency & Supply Chain Security,10
# file format and loading incompatibility,data anonymization,System Runtime Compatibility Concerns,Data Security Solutions,1
# data leakages during model training/inference/usage,secure prompt techniques,Data Exposure Concerns,Model Security Solutions,3
# system resource exhaustions,adoption/enhancment of security scanning & testing tools,Memory and Resource Security Concerns,Security Governance & Assurance,1
# system/software unsafe deserialization,memory safety & resource management techniques,Code Execution Security Concerns,Secure Runtime & Environment Configuration,3
# deployment misconfigurations,memory safety & resource management techniques,Deployment and Infrastructure Security Concerns,Secure Runtime & Environment Configuration,7
# harmful/undesired model output,dependency version upgrade,Model Output and Content Control Concerns,Dependency & Supply Chain Security,7
# system/software arbitrary code execution,modify configurations for enhanced security,Code Execution Security Concerns,Secure Infrastructure & Deployment,5
# software dependencies compatibility issues,secure deployment strategies,System Runtime Compatibility Concerns,Secure Infrastructure & Deployment,6
# risk of malicious codes in dependencies/plugins,adoption/enhancment of security scanning & testing tools,Security of Dependencies Concerns,Security Governance & Assurance,4
# outdated third-party dependency/package contains vulnerabilities,input validation and sanitization,Security of Dependencies Concerns,Secure Coding & Execution,3
# system/software open redirect,dependency version upgrade,Code Execution Security Concerns,Dependency & Supply Chain Security,4
# system/software open redirect,input validation and sanitization,Code Execution Security Concerns,Secure Coding & Execution,3
# unsafe memory usage,dependency version upgrade,Memory and Resource Security Concerns,Dependency & Supply Chain Security,13
# system resource exhaustions,dependency version upgrade,Memory and Resource Security Concerns,Dependency & Supply Chain Security,24
# system/software path traversal,dependency version upgrade,Code Execution Security Concerns,Dependency & Supply Chain Security,7
# unsafe memory usage,component removal/replacement,Memory and Resource Security Concerns,Dependency & Supply Chain Security,2
# system/software arbitrary code execution,dependency version upgrade,Code Execution Security Concerns,Dependency & Supply Chain Security,13
# system/software arbitrary code execution,component removal/replacement,Code Execution Security Concerns,Dependency & Supply Chain Security,3
# system/software path traversal,component removal/replacement,Code Execution Security Concerns,Dependency & Supply Chain Security,1
# unsafe os command execution and environment variable handling,dependency version upgrade,Code Execution Security Concerns,Dependency & Supply Chain Security,1
# unsafe os command execution and environment variable handling,component removal/replacement,Code Execution Security Concerns,Dependency & Supply Chain Security,1
# data leakages during model training/inference/usage,dependency version upgrade,Data Exposure Concerns,Dependency & Supply Chain Security,7
# security risk from deficient data quality,dependency version upgrade,Data Integrity Concerns,Dependency & Supply Chain Security,2
# data tampering during deployments,dependency version upgrade,Data Integrity Concerns,Dependency & Supply Chain Security,1
# outdated third-party dependency/package contains vulnerabilities,adoption/enhancment of security scanning & testing tools,Security of Dependencies Concerns,Security Governance & Assurance,1
# insecure communication due to missing certificates or protocols,dependency version upgrade,Secure Communication Concerns,Dependency & Supply Chain Security,7
# insecure communication due to missing certificates or protocols,adoption/enhancment of security scanning & testing tools,Secure Communication Concerns,Security Governance & Assurance,1
# system/software request forgery,dependency version upgrade,Code Execution Security Concerns,Dependency & Supply Chain Security,3
# system/software request forgery,adoption/enhancment of security scanning & testing tools,Code Execution Security Concerns,Security Governance & Assurance,1
# model input manipulations and evasions,content safety filters,Model Input and Prompt Security Concerns,Model Security Solutions,3
# harmful/undesired model output,input validation and sanitization,Model Output and Content Control Concerns,Secure Coding & Execution,5
# risk of malicious codes in dependencies/plugins,dependency version upgrade,Security of Dependencies Concerns,Dependency & Supply Chain Security,3
# system/software cross-site scripting,dependency version upgrade,Code Execution Security Concerns,Dependency & Supply Chain Security,2
# system/software unsafe deserialization,component removal/replacement,Code Execution Security Concerns,Dependency & Supply Chain Security,5
# system/software arbitrary code execution,secure deserialization practices,Code Execution Security Concerns,Secure Coding & Execution,9
# unsafe memory usage,secure code execution implementation,Memory and Resource Security Concerns,Secure Coding & Execution,5
# unsafe memory usage,memory safety & resource management techniques,Memory and Resource Security Concerns,Secure Runtime & Environment Configuration,15
# unsafe os command execution and environment variable handling,memory safety & resource management techniques,Code Execution Security Concerns,Secure Runtime & Environment Configuration,1
# unsafe memory usage,input validation and sanitization,Memory and Resource Security Concerns,Secure Coding & Execution,3
# improper authentication and authorization,dependency version upgrade,External Service Usage Security Concerns,Dependency & Supply Chain Security,4
# outdated third-party dependency/package contains vulnerabilities,dependency source vetting and control,Security of Dependencies Concerns,Dependency & Supply Chain Security,2
# risk of malicious codes in dependencies/plugins,use of dependency management tools,Security of Dependencies Concerns,Dependency & Supply Chain Security,1
# limited capabilities of security tools,use of dependency management tools,External Service Usage Security Concerns,Dependency & Supply Chain Security,1
# insecure communication due to missing certificates or protocols,secure communication protocol usage,Secure Communication Concerns,Secure Runtime & Environment Configuration,12
# insecure communication due to missing certificates or protocols,modify configurations for enhanced security,Secure Communication Concerns,Secure Infrastructure & Deployment,5
# using insecure (default) deployment configurations,secure communication protocol usage,Deployment and Infrastructure Security Concerns,Secure Runtime & Environment Configuration,3
# use of untrusted dependency sources,implementation of secure default configurations,Security of Dependencies Concerns,Secure Infrastructure & Deployment,1
# risk of malicious codes in dependencies/plugins,implementation of secure default configurations,Security of Dependencies Concerns,Secure Infrastructure & Deployment,2
# insecure communication due to missing certificates or protocols,modify configurations for enhanced compatibility,Secure Communication Concerns,Secure Runtime & Environment Configuration,3
# insecure communication due to missing certificates or protocols,secure deployment strategies,Secure Communication Concerns,Secure Infrastructure & Deployment,3
# deployment misconfigurations,secure communication protocol usage,Deployment and Infrastructure Security Concerns,Secure Runtime & Environment Configuration,11
# software dependencies compatibility issues,dependency source vetting and control,System Runtime Compatibility Concerns,Dependency & Supply Chain Security,6
# improper authentication and authorization,implementation of secure default configurations,External Service Usage Security Concerns,Secure Infrastructure & Deployment,2
# using insecure (default) deployment configurations,implementation of authentication mechanisms,Deployment and Infrastructure Security Concerns,Platform Identity & Access Management,2
# using insecure (default) deployment configurations,authorization & permission controls,Deployment and Infrastructure Security Concerns,Platform Identity & Access Management,5
# insecure communication due to missing certificates or protocols,component removal/replacement,Secure Communication Concerns,Dependency & Supply Chain Security,2
# environmental compatibility issues,secure communication protocol usage,System Runtime Compatibility Concerns,Secure Runtime & Environment Configuration,1
# software dependencies compatibility issues,secure communication protocol usage,System Runtime Compatibility Concerns,Secure Runtime & Environment Configuration,1
# software dependencies compatibility issues,secure code execution implementation,System Runtime Compatibility Concerns,Secure Coding & Execution,9
# exposed system details and information in apis,content safety filters,Secure Communication Concerns,Model Security Solutions,1
# improper authentication and authorization,secure communication protocol usage,External Service Usage Security Concerns,Secure Runtime & Environment Configuration,1
# model input manipulations and evasions,modify configurations for enhanced security,Model Input and Prompt Security Concerns,Secure Infrastructure & Deployment,1
# harmful/undesired model output,modify configurations for enhanced compatibility,Model Output and Content Control Concerns,Secure Runtime & Environment Configuration,6
# outdated third-party dependency/package contains vulnerabilities,secure file format adoption,Security of Dependencies Concerns,Secure Coding & Execution,2
# unauthorized data collection during usage,component removal/replacement,Data Exposure Concerns,Dependency & Supply Chain Security,2
# platform api availability/error,secure deployment strategies,External Service Usage Security Concerns,Secure Infrastructure & Deployment,5
# harmful/undesired model output,user consent and warning mechanisms,Model Output and Content Control Concerns,Security Governance & Assurance,2
# file format and loading incompatibility,secure file format adoption,System Runtime Compatibility Concerns,Secure Coding & Execution,6
# environmental compatibility issues,use of isolated processes for dependencies,System Runtime Compatibility Concerns,Dependency & Supply Chain Security,1
# deployment misconfigurations,use of isolated processes for dependencies,Deployment and Infrastructure Security Concerns,Dependency & Supply Chain Security,1
# use of untrusted dependency sources,dependency version upgrade,Security of Dependencies Concerns,Dependency & Supply Chain Security,3
# platform api availability/error,secure file format adoption,External Service Usage Security Concerns,Secure Coding & Execution,1
# environmental compatibility issues,secure file format adoption,System Runtime Compatibility Concerns,Secure Coding & Execution,1
# unreliable content filtering mechanism for model output,input validation and sanitization,Model Output and Content Control Concerns,Secure Coding & Execution,3
# limited capabilities of security tools,input validation and sanitization,External Service Usage Security Concerns,Secure Coding & Execution,2
# limited capabilities of security tools,dependency version upgrade,External Service Usage Security Concerns,Dependency & Supply Chain Security,3
# environmental compatibility issues,dependency source vetting and control,System Runtime Compatibility Concerns,Dependency & Supply Chain Security,2
# limited capabilities of security tools,component removal/replacement,External Service Usage Security Concerns,Dependency & Supply Chain Security,1
# risk of malicious codes in dependencies/plugins,secure deployment strategies,Security of Dependencies Concerns,Secure Infrastructure & Deployment,6
# software dependencies compatibility issues,memory safety & resource management techniques,System Runtime Compatibility Concerns,Secure Runtime & Environment Configuration,5
# model input manipulations and evasions,dependency version upgrade,Model Input and Prompt Security Concerns,Dependency & Supply Chain Security,2
# flawed or insecure prompt/template design,dependency version upgrade,Model Input and Prompt Security Concerns,Dependency & Supply Chain Security,3
# data leakages during model training/inference/usage,modify configurations for enhanced compatibility,Data Exposure Concerns,Secure Runtime & Environment Configuration,1
# failure of model generation control parameters,dependency version upgrade,Model Output and Content Control Concerns,Dependency & Supply Chain Security,1
# failure of model generation control parameters,modify configurations for enhanced security,Model Output and Content Control Concerns,Secure Infrastructure & Deployment,4
# unreliable content filtering mechanism for model output,secure prompt techniques,Model Output and Content Control Concerns,Model Security Solutions,1
# software dependencies compatibility issues,secure file format adoption,System Runtime Compatibility Concerns,Secure Coding & Execution,1
# data tampering during deployments,dependency source vetting and control,Data Integrity Concerns,Dependency & Supply Chain Security,3
# platform api availability/error,dependency source vetting and control,External Service Usage Security Concerns,Dependency & Supply Chain Security,2
# platform api availability/error,modify configurations for enhanced security,External Service Usage Security Concerns,Secure Infrastructure & Deployment,4
# system resource exhaustions,dependency source vetting and control,Memory and Resource Security Concerns,Dependency & Supply Chain Security,1
# limited capabilities of security tools,modify configurations for enhanced compatibility,External Service Usage Security Concerns,Secure Runtime & Environment Configuration,1
# limited capabilities of security tools,modify configurations for enhanced security,External Service Usage Security Concerns,Secure Infrastructure & Deployment,1
# platform api availability/error,dependency version upgrade,External Service Usage Security Concerns,Dependency & Supply Chain Security,2
# flawed or insecure prompt/template design,modify configurations for enhanced compatibility,Model Input and Prompt Security Concerns,Secure Runtime & Environment Configuration,1
# file format and loading incompatibility,component removal/replacement,System Runtime Compatibility Concerns,Dependency & Supply Chain Security,3
# deployment misconfigurations,implementation of authentication mechanisms,Deployment and Infrastructure Security Concerns,Platform Identity & Access Management,3
# software dependencies compatibility issues,implementation of authentication mechanisms,System Runtime Compatibility Concerns,Platform Identity & Access Management,2
# improper authentication and authorization,modify configurations for enhanced compatibility,External Service Usage Security Concerns,Secure Runtime & Environment Configuration,4
# platform api availability/error,authorization & permission controls,External Service Usage Security Concerns,Platform Identity & Access Management,4
# platform api availability/error,modify configurations for enhanced compatibility,External Service Usage Security Concerns,Secure Runtime & Environment Configuration,2
# limited capabilities of security tools,secure code execution implementation,External Service Usage Security Concerns,Secure Coding & Execution,1
# data leakages during model training/inference/usage,secure code execution implementation,Data Exposure Concerns,Secure Coding & Execution,4
# data leakages during model training/inference/usage,modify configurations for enhanced security,Data Exposure Concerns,Secure Infrastructure & Deployment,2
# platform api availability/error,implementation of authentication mechanisms,External Service Usage Security Concerns,Platform Identity & Access Management,4
# use of untrusted dependency sources,implementation of authentication mechanisms,Security of Dependencies Concerns,Platform Identity & Access Management,1
# risk of malicious codes in dependencies/plugins,implementation of authentication mechanisms,Security of Dependencies Concerns,Platform Identity & Access Management,2
# use of untrusted dependency sources,modify configurations for enhanced security,Security of Dependencies Concerns,Secure Infrastructure & Deployment,3
# file format and loading incompatibility,secure deployment strategies,System Runtime Compatibility Concerns,Secure Infrastructure & Deployment,2
# platform api availability/error,component removal/replacement,External Service Usage Security Concerns,Dependency & Supply Chain Security,1
# system resource exhaustions,secure file format adoption,Memory and Resource Security Concerns,Secure Coding & Execution,1
# data tampering during deployments,user consent and warning mechanisms,Data Integrity Concerns,Security Governance & Assurance,1
# data tampering during deployments,secure code execution implementation,Data Integrity Concerns,Secure Coding & Execution,1
# harmful/undesired model output,component removal/replacement,Model Output and Content Control Concerns,Dependency & Supply Chain Security,2
# using insecure (default) deployment configurations,modify configurations for enhanced compatibility,Deployment and Infrastructure Security Concerns,Secure Runtime & Environment Configuration,3
# unreliable content filtering mechanism for model output,user consent and warning mechanisms,Model Output and Content Control Concerns,Security Governance & Assurance,1
# risk of malicious codes in dependencies/plugins,component removal/replacement,Security of Dependencies Concerns,Dependency & Supply Chain Security,3
# use of untrusted dependency sources,component removal/replacement,Security of Dependencies Concerns,Dependency & Supply Chain Security,2
# flawed or insecure prompt/template design,memory safety & resource management techniques,Model Input and Prompt Security Concerns,Secure Runtime & Environment Configuration,1
# harmful/undesired model output,memory safety & resource management techniques,Model Output and Content Control Concerns,Secure Runtime & Environment Configuration,1
# system resource exhaustions,secure code execution implementation,Memory and Resource Security Concerns,Secure Coding & Execution,5
# flawed or insecure prompt/template design,data guardrails,Model Input and Prompt Security Concerns,Data Security Solutions,1
# model input manipulations and evasions,adoption/enhancment of security scanning & testing tools,Model Input and Prompt Security Concerns,Security Governance & Assurance,2
# risk of malicious codes in dependencies/plugins,modify configurations for enhanced compatibility,Security of Dependencies Concerns,Secure Runtime & Environment Configuration,1
# system/software arbitrary code execution,modify configurations for enhanced compatibility,Code Execution Security Concerns,Secure Runtime & Environment Configuration,1
# environmental compatibility issues,secure code execution implementation,System Runtime Compatibility Concerns,Secure Coding & Execution,1
# data tampering during deployments,component removal/replacement,Data Integrity Concerns,Dependency & Supply Chain Security,2
# unauthorized data collection during usage,data guardrails,Data Exposure Concerns,Data Security Solutions,1
# file format and loading incompatibility,memory safety & resource management techniques,System Runtime Compatibility Concerns,Secure Runtime & Environment Configuration,1
# flawed or insecure prompt/template design,content safety filters,Model Input and Prompt Security Concerns,Model Security Solutions,2
# software dependencies compatibility issues,content safety filters,System Runtime Compatibility Concerns,Model Security Solutions,1
# system/software unsafe deserialization,input validation and sanitization,Code Execution Security Concerns,Secure Coding & Execution,4
# unsafe memory usage,secure deserialization practices,Memory and Resource Security Concerns,Secure Coding & Execution,2
# system resource exhaustions,secure deserialization practices,Memory and Resource Security Concerns,Secure Coding & Execution,2
# system resource exhaustions,input validation and sanitization,Memory and Resource Security Concerns,Secure Coding & Execution,3
# unreliable content filtering mechanism for model output,modify configurations for enhanced security,Model Output and Content Control Concerns,Secure Infrastructure & Deployment,1
# system/software arbitrary code execution,input validation and sanitization,Code Execution Security Concerns,Secure Coding & Execution,16
# unsafe os command execution and environment variable handling,input validation and sanitization,Code Execution Security Concerns,Secure Coding & Execution,7
# risk of malicious codes in dependencies/plugins,input validation and sanitization,Security of Dependencies Concerns,Secure Coding & Execution,2
# use of untrusted dependency sources,input validation and sanitization,Security of Dependencies Concerns,Secure Coding & Execution,1
# unauthorized data collection during usage,secure code execution implementation,Data Exposure Concerns,Secure Coding & Execution,1
# unauthorized data collection during usage,input validation and sanitization,Data Exposure Concerns,Secure Coding & Execution,2
# system/software unsafe deserialization,implementation of secure default configurations,Code Execution Security Concerns,Secure Infrastructure & Deployment,3
# system/software unsafe deserialization,user consent and warning mechanisms,Code Execution Security Concerns,Security Governance & Assurance,3
# system/software arbitrary code execution,implementation of secure default configurations,Code Execution Security Concerns,Secure Infrastructure & Deployment,4
# exposed system details and information in apis,input validation and sanitization,Secure Communication Concerns,Secure Coding & Execution,3
# system/software request forgery,input validation and sanitization,Code Execution Security Concerns,Secure Coding & Execution,2
# exposed system details and information in apis,implementation of secure default configurations,Secure Communication Concerns,Secure Infrastructure & Deployment,1
# exposed system details and information in apis,secure communication protocol usage,Secure Communication Concerns,Secure Runtime & Environment Configuration,1
# exposed system details and information in apis,modify configurations for enhanced security,Secure Communication Concerns,Secure Infrastructure & Deployment,2
# exposed system details and information in apis,secure deployment strategies,Secure Communication Concerns,Secure Infrastructure & Deployment,1
# risk of malicious codes in dependencies/plugins,user consent and warning mechanisms,Security of Dependencies Concerns,Security Governance & Assurance,3
# exposed system details and information in apis,secure code execution implementation,Secure Communication Concerns,Secure Coding & Execution,1
# unauthorized data collection during usage,data anonymization,Data Exposure Concerns,Data Security Solutions,1
# data leakages during model training/inference/usage,component removal/replacement,Data Exposure Concerns,Dependency & Supply Chain Security,1
# exposed system details and information in apis,data anonymization,Secure Communication Concerns,Data Security Solutions,1
# exposed system details and information in apis,component removal/replacement,Secure Communication Concerns,Dependency & Supply Chain Security,1
# risk of malicious codes in dependencies/plugins,data anonymization,Security of Dependencies Concerns,Data Security Solutions,1
# data tampering during deployments,implementation of secure default configurations,Data Integrity Concerns,Secure Infrastructure & Deployment,1
# data tampering during deployments,secure deployment strategies,Data Integrity Concerns,Secure Infrastructure & Deployment,2
# data tampering during deployments,modify configurations for enhanced security,Data Integrity Concerns,Secure Infrastructure & Deployment,1
# software dependencies compatibility issues,implementation of secure default configurations,System Runtime Compatibility Concerns,Secure Infrastructure & Deployment,1
# insecure communication due to missing certificates or protocols,dependency source vetting and control,Secure Communication Concerns,Dependency & Supply Chain Security,2
# use of untrusted dependency sources,secure communication protocol usage,Security of Dependencies Concerns,Secure Runtime & Environment Configuration,2
# risk of malicious codes in dependencies/plugins,secure communication protocol usage,Security of Dependencies Concerns,Secure Runtime & Environment Configuration,2
# data leakages during model training/inference/usage,implementation of secure default configurations,Data Exposure Concerns,Secure Infrastructure & Deployment,1
# data leakages during model training/inference/usage,input validation and sanitization,Data Exposure Concerns,Secure Coding & Execution,3
# using insecure (default) deployment configurations,input validation and sanitization,Deployment and Infrastructure Security Concerns,Secure Coding & Execution,3
# security risk from deficient data quality,implementation of secure default configurations,Data Integrity Concerns,Secure Infrastructure & Deployment,1
# security risk from deficient data quality,input validation and sanitization,Data Integrity Concerns,Secure Coding & Execution,2
# security risk from deficient data quality,user consent and warning mechanisms,Data Integrity Concerns,Security Governance & Assurance,1
# unsafe os command execution and environment variable handling,secure deployment strategies,Code Execution Security Concerns,Secure Infrastructure & Deployment,1
# model input manipulations and evasions,secure code execution implementation,Model Input and Prompt Security Concerns,Secure Coding & Execution,3
# model input manipulations and evasions,memory safety & resource management techniques,Model Input and Prompt Security Concerns,Secure Runtime & Environment Configuration,1
# system/software arbitrary code execution,memory safety & resource management techniques,Code Execution Security Concerns,Secure Runtime & Environment Configuration,1
# model input manipulations and evasions,user consent and warning mechanisms,Model Input and Prompt Security Concerns,Security Governance & Assurance,1
# exposed system details and information in apis,user consent and warning mechanisms,Secure Communication Concerns,Security Governance & Assurance,1
# system/software request forgery,user consent and warning mechanisms,Code Execution Security Concerns,Security Governance & Assurance,1
# system/software cross-site scripting,input validation and sanitization,Code Execution Security Concerns,Secure Coding & Execution,2
# risk of malicious codes in dependencies/plugins,secure deserialization practices,Security of Dependencies Concerns,Secure Coding & Execution,2
# use of untrusted dependency sources,secure deserialization practices,Security of Dependencies Concerns,Secure Coding & Execution,1
# limited capabilities of security tools,user consent and warning mechanisms,External Service Usage Security Concerns,Security Governance & Assurance,1
# using insecure (default) deployment configurations,secure code execution implementation,Deployment and Infrastructure Security Concerns,Secure Coding & Execution,3
# platform api availability/error,memory safety & resource management techniques,External Service Usage Security Concerns,Secure Runtime & Environment Configuration,1
# limited capabilities of security tools,memory safety & resource management techniques,External Service Usage Security Concerns,Secure Runtime & Environment Configuration,1
# security risk from deficient data quality,secure deserialization practices,Data Integrity Concerns,Secure Coding & Execution,1
# security risk from deficient data quality,secure code execution implementation,Data Integrity Concerns,Secure Coding & Execution,1
# harmful/undesired model output,secure code execution implementation,Model Output and Content Control Concerns,Secure Coding & Execution,1
# system/software arbitrary code execution,implementation of authentication mechanisms,Code Execution Security Concerns,Platform Identity & Access Management,2
# model input manipulations and evasions,implementation of authentication mechanisms,Model Input and Prompt Security Concerns,Platform Identity & Access Management,2
# data leakages during model training/inference/usage,implementation of authentication mechanisms,Data Exposure Concerns,Platform Identity & Access Management,1
# exposed system details and information in apis,implementation of authentication mechanisms,Secure Communication Concerns,Platform Identity & Access Management,1
# data tampering during deployments,secure communication protocol usage,Data Integrity Concerns,Secure Runtime & Environment Configuration,1
# security risk from deficient data quality,content safety filters,Data Integrity Concerns,Model Security Solutions,1
# system/software request forgery,implementation of authentication mechanisms,Code Execution Security Concerns,Platform Identity & Access Management,1
# system/software request forgery,secure code execution implementation,Code Execution Security Concerns,Secure Coding & Execution,1
# system/software cross-site scripting,secure code execution implementation,Code Execution Security Concerns,Secure Coding & Execution,1
# system/software cross-site scripting,dependency source vetting and control,Code Execution Security Concerns,Dependency & Supply Chain Security,1
# file format and loading incompatibility,secure deserialization practices,System Runtime Compatibility Concerns,Secure Coding & Execution,1
# outdated third-party dependency/package contains vulnerabilities,memory safety & resource management techniques,Security of Dependencies Concerns,Secure Runtime & Environment Configuration,1
# risk of malicious codes in dependencies/plugins,authorization & permission controls,Security of Dependencies Concerns,Platform Identity & Access Management,1
# data tampering during deployments,authorization & permission controls,Data Integrity Concerns,Platform Identity & Access Management,1
#                                 issue  \
# 0  environmental compatibility issues
# 1  environmental compatibility issues
# 2        deployment misconfigurations
# 3        deployment misconfigurations
# 4         system resource exhaustions
#
#                                            solution  \
# 0  modify configurations for enhanced compatibility
# 1       modify configurations for enhanced security
# 2  modify configurations for enhanced compatibility
# 3       modify configurations for enhanced security
# 4       modify configurations for enhanced security
#
#                                    issue_sub_theme  \
# 0            System Runtime Compatibility Concerns
# 1            System Runtime Compatibility Concerns
# 2  Deployment and Infrastructure Security Concerns
# 3  Deployment and Infrastructure Security Concerns
# 4            Memory and Resource Security Concerns
#
#                            solution_sub_theme  count
# 0  Secure Runtime & Environment Configuration     15
# 1          Secure Infrastructure & Deployment      6
# 2  Secure Runtime & Environment Configuration     28
# 3          Secure Infrastructure & Deployment     50
# 4          Secure Infrastructure & Deployment     13
# Total rows: 322
